# %%
import numpy as np

def T(p,m,F,r):
    T = np.sqrt(((( 4 * p**2 * m) / F) (r) ))
    return T

p = 3.141592653
m = .2081
F = .8851
r = .128

T = T(p,m,F,r)
print ("T = ",T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 12>()
#       9 F = .8851
#      10 r = .128
# ---> 12 T = T(p,m,F,r)
#      13 print ("T = ",T)
#
# Input In [16], in T(p, m, F, r)
#       3 def T(p,m,F,r):
# ----> 4     T = np.sqrt(((( 4 * p**2 * m) / F) (r) ))
#       5     return T
#
# TypeError: 'float' object is not callable

# %% [markdown]
# ### I tried this way first and I didn't think I was doing it right. I then looked at a previous lab where we did graph and tried to copy that format but am seriously stuck

# %% [markdown]
# #

# %% [markdown]
# #

# %%
import numpy as np
import matplotlib.pyplot as plt



# %matplotlib inline

r = radius_array=np.array([.128,.153,.165,.188])
y = T_array=np.array([1.1881,1.3225,1.6129,1.8225])
F = F_array=np.array([.8851,.9504,.8404,.8475])
m = m_array=np.array ([.2081,.2081,.2081,.2081])



plt.figure(figsize=(15,10))


plt.scatter (x, y, color='blue', marker='o')


plt.xlabel('Radius (m)')
plt.ylabel('Period (T^2)')
plt.title('Period of Rotation vs Radius')



fit = y = (((m)(r))/F)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 27>()
#      22 plt.ylabel('Period (T^2)')
#      23 plt.title('Period of Rotation vs Radius')
# ---> 27 fit = y = (((m)(r))/F)
#
# TypeError: 'numpy.ndarray' object is not callable
